# %%
import pandas as pd

df = pd.read_csv("configs/classes.csv")
df.head()
# Out:
#                                           class_name    brand category  \
# 0                            Biskett_biscuit_biscuit  Biskett  biscuit
# 1  Biskett_biscuit_cookie-butter-spread-biscuit-s...  Biskett  biscuit
# 2        Biskett_biscuit_sandwich-caramelize-biscuit  Biskett  biscuit
# 3                            Bomb_bottle_unspecified     Bomb   bottle
# 4                                 Kix_ice-pop_cherry      Kix  ice-pop
#
#                                    sku  is_ours
# 0                              biscuit        1
# 1  cookie-butter-spread-biscuit-spread        1
# 2          sandwich-caramelize-biscuit        1
# 3                          unspecified        1
# 4                               cherry        1

# %%
df1 = df.class_name
df1.head()
# Out:
# 0                              Biskett_biscuit_biscuit
# 1    Biskett_biscuit_cookie-butter-spread-biscuit-s...
# 2          Biskett_biscuit_sandwich-caramelize-biscuit
# 3                              Bomb_bottle_unspecified
# 4                                   Kix_ice-pop_cherry
# Name: class_name, dtype: str

# %%
df1.to_csv("trials_classes.csv", index=False)
